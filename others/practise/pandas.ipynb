# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '0.23.4'

# %%
house_dataframe=pd.read_csv("california_housing_train.csv", sep=",")
house_dataframe.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
house_dataframe.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
house_dataframe.hist("total_rooms")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000011443048>]],
#       dtype=object)

# %%
city_names=pd.Series(['San Francisco','San Jose', 'Sacramento'])
population=pd.Series([852469, 1015785, 485199])
cities=pd.DataFrame({"City name":city_names, 'Population':population})
print(type(cities['City name']))
cities['City name']
# Out:
# <class 'pandas.core.series.Series'>
# 0    San Francisco
# 1         San Jose
# 2       Sacramento
# Name: City name, dtype: object

# %%
np.log(population)
# Out:
# 0    13.655892
# 1    13.831172
# 2    13.092314
# dtype: float64

# %%
sect_population=house_dataframe.population
sect_populationLargeThan1000 = sect_population.apply(lambda val:val if val>1000 else 0)

# %%
#house_dataframe.insert(0,'HouseAgeBigThan25Years',False)
#del house_dataframe['HouseAgeBigThan25Years']
house_dataframe['HouseAgeBigThan25Years']=house_dataframe['housing_median_age'] > 25
del house_dataframe['HouseAgeBigThan25Years']

# %%
house_dataframe.reindex(np.random.permutation(house_dataframe.index))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2095     -114.31     34.19                15.0       5612.0          1283.0
# 385      -114.47     34.40                19.0       7650.0          1901.0
# 8767     -114.56     33.69                17.0        720.0           174.0
# 8513     -114.57     33.64                14.0       1501.0           337.0
# 4131     -114.57     33.57                20.0       1454.0           326.0
# 2908     -114.58     33.63                29.0       1387.0           236.0
# 9029     -114.58     33.61                25.0       2907.0           680.0
# 8144     -114.59     34.83                41.0        812.0           168.0
# 9722     -114.59     33.61                34.0       4789.0          1175.0
# 13162    -114.60     34.83                46.0       1497.0           309.0
# 6651     -114.60     33.62                16.0       3741.0           801.0
# ...
