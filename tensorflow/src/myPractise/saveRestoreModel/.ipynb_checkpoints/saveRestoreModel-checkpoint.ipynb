# %%
from __future__ import absolute_import, division, print_function

import os

import tensorflow as tf
from tensorflow import keras

tf.__version__

train_images,train_labels, test_images, test_labels = None, None, None, None

# %%
def loadDatasets():
    global train_images,train_labels, test_images, test_labels
    dbPath = os.getcwd() + r"\..\mnist\datasets\mnist.npz"
    (train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data(path= dbPath)

    train_labels = train_labels[:1000]
    test_labels = test_labels[:1000]

    train_images = train_images[:1000].reshape(-1, 28 * 28) / 255.0
    test_images = test_images[:1000].reshape(-1, 28 * 28) / 255.0

# %%
def create_model():
      model = tf.keras.models.Sequential([
            keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(784,)),
            keras.layers.Dropout(0.2),
            keras.layers.Dense(10, activation=tf.nn.softmax)])

      model.compile(optimizer=tf.keras.optimizers.Adam(),
                loss=tf.keras.losses.sparse_categorical_crossentropy,
                metrics=['accuracy'])

      return model

# %%
def trainModel(model):
    global checkpoint_path, checkpoint_dir
    checkpoint_path = 'trainCheckPoint/cp.ckpt'
    checkpoint_dir = os.path.dirname(checkpoint_path)
    print(f"checkpoint:{checkpoint_path},checkpoint_dir:{checkpoint_dir}")
    
    # Create checkpoint callback
    cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                     save_weights_only=True,
                                                     verbose=1)

    model = create_model()

    model.fit(train_images, train_labels,  epochs = 10,
              validation_data = (test_images,test_labels),
              callbacks = [cp_callback])  # pass callback to training   
    return model, checkpoint_dir

# %%
def evaluateModel(model):
    loss, acc = model.evaluate(test_images, test_labels)
    print("loss: {:5.2f}% accuracy: {:5.2f}%".format(loss, 100*acc))

# %%
if __name__ == '__main__':
    isLoadDatabasetsNeeded = True
    if isLoadDatabasetsNeeded:
        loadDatasets()
    model_A = create_model()
    model_A.summary()
    model_A, checkpoint_dir = trainModel(model_A)
    checkpoint_latest = tf.train.latest_checkpoint(checkpoint_dir)
    
    evaluateModel(model_A)
    
    model_B = create_model()
    model_B.summary()
    print("before load weights")
    evaluateModel(model_B)
    
    model_B.load_weights(checkpoint_latest)
    print("after load weights")    
    evaluateModel(model_B)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# checkpoint:trainCheckPoint/cp.ckpt,checkpoint_dir:trainCheckPoint
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/10
#  896/1000 [=========================>....] - ETA: 0s - loss: 1.2306 - acc: 0.6629
# Epoch 00001: saving model to trainCheckPoint/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x0000022FA5CCF198>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 1000/1000 [==============================] - 1s 1ms/step - loss: 1.1699 - acc: 0.6800 - val_loss: 0.7195 - val_acc: 0.7820
# Epoch 2/10
#  928/1000 [==========================>...] - ETA: 0s - loss: 0.4392 - acc: 0.8728
# Epoch 00002: saving model to trainCheckPoint/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x0000022FA5CCF198>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.4357 - acc: 0.8750 - val_loss: 0.5419 - val_acc: 0.8310
# Epoch 3/10
#  928/1000 [==========================>...] - ETA: 0s - loss: 0.3003 - acc: 0.9181
# Epoch 00003: saving model to trainCheckPoint/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x0000022FA5CCF198>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 1000/1000 [==============================] - 1s 638us/step - loss: 0.3016 - acc: 0.9180 - val_loss: 0.4635 - val_acc: 0.8550
# Epoch 4/10
#  992/1000 [============================>.] - ETA: 0s - loss: 0.2054 - acc: 0.9567
# Epoch 00004: saving model to trainCheckPoint/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x0000022FA5CCF198>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 1000/1000 [==============================] - 1s 664us/step - loss: 0.2069 - acc: 0.9550 - val_loss: 0.4196 - val_acc: 0.8710
# Epoch 5/10
#  992/1000 [============================>.] - ETA: 0s - loss: 0.1559 - acc: 0.9677- ETA: 0s - loss: 0.1533 - acc: 0.96
# Epoch 00005: saving model to trainCheckPoint/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x0000022FA5CCF198>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 1000/1000 [==============================] - 1s 700us/step - loss: 0.1567 - acc: 0.9680 - val_loss: 0.4356 - val_acc: 0.8520
# Epoch 6/10
#  992/1000 [============================>.] - ETA: 0s - loss: 0.1188 - acc: 0.9788
# Epoch 00006: saving model to trainCheckPoint/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x0000022FA5CCF198>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 1000/1000 [==============================] - 1s 631us/step - loss: 0.1193 - acc: 0.9790 - val_loss: 0.4234 - val_acc: 0.8660
# Epoch 7/10
#  896/1000 [=========================>....] - ETA: 0s - loss: 0.0861 - acc: 0.9877
# Epoch 00007: saving model to trainCheckPoint/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x0000022FA5CCF198>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 1000/1000 [==============================] - 1s 742us/step - loss: 0.0885 - acc: 0.9860 - val_loss: 0.4035 - val_acc: 0.8790
# Epoch 8/10
#  992/1000 [============================>.] - ETA: 0s - loss: 0.0680 - acc: 0.9940
# Epoch 00008: saving model to trainCheckPoint/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x0000022FA5CCF198>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 1000/1000 [==============================] - 1s 700us/step - loss: 0.0682 - acc: 0.9940 - val_loss: 0.4368 - val_acc: 0.8630
# Epoch 9/10
#  928/1000 [==========================>...] - ETA: 0s - loss: 0.0543 - acc: 0.9946
# Epoch 00009: saving model to trainCheckPoint/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x0000022FA5CCF198>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 1000/1000 [==============================] - 1s 605us/step - loss: 0.0535 - acc: 0.9950 - val_loss: 0.4258 - val_acc: 0.8670
# Epoch 10/10
#  928/1000 [==========================>...] - ETA: 0s - loss: 0.0444 - acc: 0.9989
# Epoch 00010: saving model to trainCheckPoint/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.Adam object at 0x0000022FA5CCF198>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 1000/1000 [==============================] - 1s 671us/step - loss: 0.0448 - acc: 0.9980 - val_loss: 0.4448 - val_acc: 0.8570
# 1000/1000 [==============================] - 0s 105us/step
# loss:  0.44% accuracy: 85.70%
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# before load weights
# 1000/1000 [==============================] - 0s 333us/step
# loss:  2.32% accuracy:  9.30%
# after load weights
# 1000/1000 [==============================] - 0s 94us/step
# loss:  0.44% accuracy: 85.70%
